# %% [markdown]
# # Covid 19 radiography database

# %% [markdown]
# Załadujmy biblioteki

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Wczytajmy metadane

# %%
covidmetadata = pd.read_excel('COVID.metadata.xlsx')
normalmetadata = pd.read_excel('Normal.metadata.xlsx')
lung_opacity = pd.read_excel('Lung_Opacity.metadata.xlsx')
viralpneumonia = pd.read_excel('Viral Pneumonia.metadata.xlsx')

# %%
normalmetadata
# Out:
#           FILE NAME FORMAT     SIZE  \
# 0          NORMAL-1    PNG  256*256
# 1          NORMAL-2    PNG  256*256
# 2          NORMAL-3    PNG  256*256
# 3          NORMAL-4    PNG  256*256
# 4          NORMAL-5    PNG  256*256
# ...             ...    ...      ...
# 10187  NORMAL-10188    PNG  256*256
# 10188  NORMAL-10189    PNG  256*256
# 10189  NORMAL-10190    PNG  256*256
# 10190  NORMAL-10191    PNG  256*256
# 10191  NORMAL-10192    PNG  256*256
#
#                                                      URL
# 0      https://www.kaggle.com/c/rsna-pneumonia-detect...
# 1      https://www.kaggle.com/c/rsna-pneumonia-detect...
# 2      https://www.kaggle.com/c/rsna-pneumonia-detect...
# 3      https://www.kaggle.com/c/rsna-pneumonia-detect...
# 4      https://www.kaggle.com/c/rsna-pneumonia-detect...
# ...                                                  ...
# 10187  https://www.kaggle.com/paultimothymooney/chest...
# 10188  https://www.kaggle.com/paultimothymooney/chest...
# ...

# %%
normalmetadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10192 entries, 0 to 10191
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   FILE NAME  10192 non-null  object
#  1   FORMAT     10192 non-null  object
#  2   SIZE       10192 non-null  object
#  3   URL        10192 non-null  object
# dtypes: object(4)
# memory usage: 318.6+ KB

# %%
covidmetadata
# Out:
#        FILE NAME FORMAT     SIZE  \
# 0        COVID-1    PNG  256*256
# 1        COVID-2    PNG  256*256
# 2        COVID-3    PNG  256*256
# 3        COVID-4    PNG  256*256
# 4        COVID-5    PNG  256*256
# ...          ...    ...      ...
# 3611  COVID-3612    PNG  256*256
# 3612  COVID-3613    PNG  256*256
# 3613  COVID-3614    PNG  256*256
# 3614  COVID-3615    PNG  256*256
# 3615  COVID-3616    PNG  256*256
#
#                                                     URL
# 0     https://sirm.org/category/senza-categoria/covi...
# 1     https://sirm.org/category/senza-categoria/covi...
# 2     https://sirm.org/category/senza-categoria/covi...
# 3     https://sirm.org/category/senza-categoria/covi...
# 4     https://sirm.org/category/senza-categoria/covi...
# ...                                                 ...
# 3611  https://bimcv.cipf.es/bimcv-projects/bimcv-cov...
# 3612  https://bimcv.cipf.es/bimcv-projects/bimcv-cov...
# ...

# %%
covidmetadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3616 entries, 0 to 3615
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   FILE NAME  3616 non-null   object
#  1   FORMAT     3616 non-null   object
#  2   SIZE       3616 non-null   object
#  3   URL        3616 non-null   object
# dtypes: object(4)
# memory usage: 113.1+ KB

# %%
lung_opacity
# Out:
#               FILE NAME FORMAT     SIZE  \
# 0        Lung_Opacity-1    PNG  256*256
# 1        Lung_Opacity-2    PNG  256*256
# 2        Lung_Opacity-3    PNG  256*256
# 3        Lung_Opacity-4    PNG  256*256
# 4        Lung_Opacity-5    PNG  256*256
# ...                 ...    ...      ...
# 6007  Lung_Opacity-6008    PNG  256*256
# 6008  Lung_Opacity-6009    PNG  256*256
# 6009  Lung_Opacity-6010    PNG  256*256
# 6010  Lung_Opacity-6011    PNG  256*256
# 6011  Lung_Opacity-6012    PNG  256*256
#
#                                                     URL
# 0     https://www.kaggle.com/c/rsna-pneumonia-detect...
# 1     https://www.kaggle.com/c/rsna-pneumonia-detect...
# 2     https://www.kaggle.com/c/rsna-pneumonia-detect...
# 3     https://www.kaggle.com/c/rsna-pneumonia-detect...
# 4     https://www.kaggle.com/c/rsna-pneumonia-detect...
# ...                                                 ...
# 6007  https://www.kaggle.com/c/rsna-pneumonia-detect...
# ...

# %%
lung_opacity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6012 entries, 0 to 6011
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   FILE NAME  6012 non-null   object
#  1   FORMAT     6012 non-null   object
#  2   SIZE       6012 non-null   object
#  3   URL        6012 non-null   object
# dtypes: object(4)
# memory usage: 188.0+ KB

# %%
viralpneumonia
# Out:
#                  FILE NAME FORMAT     SIZE  \
# 0        Viral Pneumonia-1    PNG  256*256
# 1        Viral Pneumonia-2    PNG  256*256
# 2        Viral Pneumonia-3    PNG  256*256
# 3        Viral Pneumonia-4    PNG  256*256
# 4        Viral Pneumonia-5    PNG  256*256
# ...                    ...    ...      ...
# 1340  Viral Pneumonia-1341    PNG  256*256
# 1341  Viral Pneumonia-1342    PNG  256*256
# 1342  Viral Pneumonia-1343    PNG  256*256
# 1343  Viral Pneumonia-1344    PNG  256*256
# 1344  Viral Pneumonia-1345    PNG  256*256
#
#                                                     URL
# 0     https://www.kaggle.com/paultimothymooney/chest...
# 1     https://www.kaggle.com/paultimothymooney/chest...
# 2     https://www.kaggle.com/paultimothymooney/chest...
# 3     https://www.kaggle.com/paultimothymooney/chest...
# 4     https://www.kaggle.com/paultimothymooney/chest...
# ...                                                 ...
# ...

# %%
viralpneumonia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1345 entries, 0 to 1344
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   FILE NAME  1345 non-null   object
#  1   FORMAT     1345 non-null   object
#  2   SIZE       1345 non-null   object
#  3   URL        1345 non-null   object
# dtypes: object(4)
# memory usage: 42.2+ KB

# %% [markdown]
# Widzimy, że wszystkie tabele są wypełnione. Nie ma żadnych braków danych

# %%
import random

# %%
from PIL import Image

# %% [markdown]
# # Przykładowe zdjęcia

# %% [markdown]
# ## Normal

# %%
image=Image.open("./Normal/"+normalmetadata.iloc[random.randint(0,len(normalmetadata))]["FILE NAME"]+".png")
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=299x299 at 0x1CE5C967820>

# %% [markdown]
# Zdrowe płuca, bez przyciemnionego miąższu.

# %% [markdown]
# ## COVID

# %%
image=Image.open("./COVID/"+covidmetadata.iloc[random.randint(0,len(covidmetadata))]["FILE NAME"]+".png")
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=299x299 at 0x1CE5C967820>

# %% [markdown]
# Widzimy typowe dla covida częściowe lub całkowite wypełnienie pęcherzyków płucnych płynem. Pogrubienie przegród
# międzyzrazikowych i śródzrazikowych

# %% [markdown]
# ## Lung Opacity

# %%
image=Image.open("./Lung_Opacity/"+lung_opacity.iloc[random.randint(0,len(lung_opacity))]["FILE NAME"]+".png")
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=299x299 at 0x1CE5C88F2B0>

# %% [markdown]
# Nieprzezroczystość płuc, w tym folderze znalazły się zdjęcia pacjentów z chorobami płuc różnych od covida czy zapalenia płuc.

# %% [markdown]
# ## Viral Pneumonia

# %%
image=Image.open("./Viral Pneumonia/"+viralpneumonia.iloc[random.randint(0,len(viralpneumonia))]["FILE NAME"]+".png")
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=299x299 at 0x1CE5C98B1C0>

# %%
image=Image.open("./Viral Pneumonia/"+viralpneumonia.iloc[random.randint(0,len(viralpneumonia))]["FILE NAME"]+".png")
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=299x299 at 0x1CE5CBB7F70>

# %% [markdown]
# Typowe dla zapalenia płuc jest zaciemnienie miąższu płuc.

# %% [markdown]
# ## Nietypowe zdjęcia

# %% [markdown]
# ### Naniesione strzałki oraz data

# %%
image = Image.open("./COVID/Covid-168.png")
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=299x299 at 0x1CE5C98B100>

# %% [markdown]
# ### Źle wycięte zdjęcie

# %%
image = Image.open("./COVID/Covid-187.png")
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=299x299 at 0x1CE5C98B610>

# %% [markdown]
# ### Zbyt jasne zdjęcie oraz zła pozycja badanego

# %%
image = Image.open("./COVID/Covid-324.png")
display(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=299x299 at 0x1CE5C98B9A0>

# %% [markdown]
# # Wnioski

# %% [markdown]
# 1. Baza danych posiada bardzo dużo zdjęć oraz jest pogrupowana według chorób.
# 2. Plusem jest, że każde zdjęcie jest takiego samego rozmiaru.
# 3. Dotkliwy jest brak danych o pacjentach, ich wieku, płci.
# 4. Metadane są praktycznie znikome.
# 5. Brakuje również informacji o tym czy zdjęcia są wykonywane AP czy PA, co może mieć duży wpływ na tworzenie i uczenie modelu.
# 6. Na podstawie przykładów widzimy, że niektóre zdjęcia nie nadają się do wczytywanie ponieważ są np. przetworzone przez lekarzy, są narysowane na nich strzałki, widnieją daty, są źle wycięte albo krzywo zrobione.
